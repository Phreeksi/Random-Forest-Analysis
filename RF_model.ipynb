# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
data = pd.read_csv("churn_clean.csv")

# %%
columns = ["State", "Area", "Marital", "Gender","InternetService","Contract", "Age", "Income","Children", "Outage_sec_perweek", "Email", "Contacts",  "MonthlyCharge", "Bandwidth_GB_Year", "Tenure"]

# %%
cat_var = ["State", "Area", "Marital", "Gender","InternetService","Contract"]

# %%
updated_data = data[columns]

# %%
updated_data.duplicated().sum()
# Out:
# 0

# %%
updated_data.isna().sum()
# Out:
# State                    0
# Area                     0
# Marital                  0
# Gender                   0
# InternetService       2129
# Contract                 0
# Age                      0
# Income                   0
# Children                 0
# Outage_sec_perweek       0
# Email                    0
# Contacts                 0
# MonthlyCharge            0
# Bandwidth_GB_Year        0
# Tenure                   0
# dtype: int64

# %%
updated_data = updated_data.fillna("None")
updated_data.isna().sum()
# Out:
# State                 0
# Area                  0
# Marital               0
# Gender                0
# InternetService       0
# Contract              0
# Age                   0
# Income                0
# Children              0
# Outage_sec_perweek    0
# Email                 0
# Contacts              0
# MonthlyCharge         0
# Bandwidth_GB_Year     0
# Tenure                0
# dtype: int64

# %%
updated_data.describe()
# Out:
#                 Age         Income    Children  Outage_sec_perweek  \
# count  10000.000000   10000.000000  10000.0000        10000.000000
# mean      53.078400   39806.926771      2.0877           10.001848
# std       20.698882   28199.916702      2.1472            2.976019
# min       18.000000     348.670000      0.0000            0.099747
# 25%       35.000000   19224.717500      0.0000            8.018214
# 50%       53.000000   33170.605000      1.0000           10.018560
# 75%       71.000000   53246.170000      3.0000           11.969485
# max       89.000000  258900.700000     10.0000           21.207230
#
#               Email      Contacts  MonthlyCharge  Bandwidth_GB_Year  \
# count  10000.000000  10000.000000   10000.000000       10000.000000
# mean      12.016000      0.994200     172.624816        3392.341550
# std        3.025898      0.988466      42.943094        2185.294852
# min        1.000000      0.000000      79.978860         155.506715
# 25%       10.000000      0.000000     139.979239        1236.470827
# 50%       12.000000      1.000000     167.484700        3279.536903
# 75%       14.000000      2.000000     200.734725        5586.141370
# max       23.000000      7.000000     290.160419        7158.981530
#
#              Tenure
# count  10000.000000
# mean      34.526188
# std       26.443063
# min        1.000259
# 25%        7.917694
# 50%       35.430507
# 75%       61.479795
# max       71.999280

# %%
updated_data[cat_var].describe()
# Out:
#         State      Area   Marital  Gender InternetService        Contract
# count   10000     10000     10000   10000           10000           10000
# unique     52         3         5       3               3               3
# top        TX  Suburban  Divorced  Female     Fiber Optic  Month-to-month
# freq      603      3346      2092    5025            4408            5456

# %%
updated_data = pd.get_dummies(updated_data, columns= cat_var, dtype=int)
updated_data
# Out:
#       Age    Income  Children  Outage_sec_perweek  Email  Contacts  \
# 0      68  28561.99         0            7.978323     10         0
# 1      27  21704.77         1           11.699080     12         0
# 2      50   9609.57         4           10.752800      9         0
# 3      48  18925.23         1           14.913540     15         2
# 4      83  40074.19         0            8.147417     16         2
# ...   ...       ...       ...                 ...    ...       ...
# 9995   23  55723.74         3            9.415935     12         2
# 9996   48  34129.34         4            6.740547     15         2
# 9997   48  45983.43         1            6.590911     10         0
# 9998   39  16667.58         1           12.071910     14         1
# 9999   28   9020.92         1           11.754720     17         1
#
#       MonthlyCharge  Bandwidth_GB_Year     Tenure  State_AK  ...  \
# 0        172.455519         904.536110   6.795513         1  ...
# 1        242.632554         800.982766   1.156681         0  ...
# 2        159.947583        2054.706961  15.754144         0  ...
# 3        119.956840        2164.579412  17.087227         0  ...
# 4        149.948316         271.493436   1.670972         0  ...
# ...             ...                ...        ...       ...  ...
# 9995     159.979400        6511.252601  68.197130         0  ...
# 9996     207.481100        5695.951810  61.040370         0  ...
# 9997     169.974100        4159.305799  47.416890         0  ...
# 9998     252.624000        6468.456752  71.095600         0  ...
# 9999     217.484000        5857.586167  63.350860         0  ...
#
#       Marital_Widowed  Gender_Female  Gender_Male  Gender_Nonbinary  \
# 0                   1              0            1                 0
# 1                   0              1            0                 0
# 2                   1              1            0                 0
# 3                   0              0            1                 0
# 4                   0              0            1                 0
# ...               ...            ...          ...               ...
# 9995                0              0            1                 0
# 9996                0              0            1                 0
# 9997                0              1            0                 0
# 9998                0              0            1                 0
# 9999                0              0            1                 0
#
#       InternetService_DSL  InternetService_Fiber Optic  InternetService_None  \
# 0                       0                            1                     0
# 1                       0                            1                     0
# 2                       1                            0                     0
# 3                       1                            0                     0
# 4                       0                            1                     0
# ...                   ...                          ...                   ...
# 9995                    1                            0                     0
# 9996                    0                            1                     0
# 9997                    0                            1                     0
# 9998                    0                            1                     0
# 9999                    0                            1                     0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two Year
# 0                           0                  1                  0
# 1                           1                  0                  0
# 2                           0                  0                  1
# 3                           0                  0                  1
# 4                           1                  0                  0
# ...                       ...                ...                ...
# 9995                        1                  0                  0
# 9996                        0                  0                  1
# 9997                        1                  0                  0
# 9998                        0                  0                  1
# 9999                        1                  0                  0
#
# [10000 rows x 78 columns]

# %%
#To CSV
updated_data.to_csv("updated_data.csv")

# %%
y = updated_data["Tenure"]
X = updated_data.drop(columns= "Tenure")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state= 42)

# %%
#To CSV
X_train.to_csv("X_train.csv")
X_test.to_csv("X_test.csv")
y_train.to_csv("y_train.csv")
y_test.to_csv("y_test.csv")

# %%
rf = RandomForestRegressor().fit(X_train, y_train)

# %%
y_pred = rf.predict(X_test)
y_pred_train = rf.predict(X_train)

# %%
mae1 = mean_absolute_error(y_test, y_pred)
mse1 = mean_squared_error(y_test, y_pred)
rmse1 = np.sqrt(mse1)
r_squared1 = r2_score(y_test, y_pred)

mae2 = mean_absolute_error(y_train, y_pred_train)
mse2 = mean_squared_error(y_train, y_pred_train)
rmse2 = np.sqrt(mse2)
r_squared2 = r2_score(y_train, y_pred_train)

# %%
print(f"MAE Train: {mae2} Test: {mae1}")
print(f"MSE Train: {mse2}  Test: {mse1}")
print(f"RMSE Train: {rmse2}  Test: {rmse1}")
print(f"R_quared Train: {r_squared2}  Test: {r_squared1}")
# Out:
# MAE Train: 0.3496807968215396 Test: 0.9052343245654966
# MSE Train: 0.2015941595084817  Test: 1.3519193839922272
# RMSE Train: 0.44899238246153095  Test: 1.162720681845914
# R_quared Train: 0.9997120796748322  Test: 0.9980587605763507
